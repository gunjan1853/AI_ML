# %%
import cv2

# %%
img = cv2.imread("../Img/women.jpeg")

# %%
media_blur=cv2.medianBlur(img,13)

# %%
cv2.imshow("Original",img)
cv2.imshow("MedianBlur",media_blur)

# %%
cv2.waitKey(0)
cv2.destroyAllWindows()
