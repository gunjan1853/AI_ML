# %%
import cv2

# %%
import numpy as np

# %%
img=cv2.imread("Img/fruits.jpeg")

# %%
img_resize=cv2.resize(img,(500,500))

# %%
cv2.imshow("original",img_resize)

# %%
cv2.waitKey(0)
# Out:
# -1

# %%
img_flip=cv2.flip(img,0)

# %%
cv2.imshow("original",img_flip)
cv2.waitKey(0)
# Out:
# -1
